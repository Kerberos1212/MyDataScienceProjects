# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler 
from sklearn.decomposition import PCA 
# %matplotlib notebook

# %%
def main():
    df = pd.read_csv('food-consumption.csv', header = 0, sep = ',')
    X = df.iloc[:, 1:].values 
    print('----shape of training data------')
    print(X.shape)
    sc = StandardScaler()  
    X = sc.fit_transform(X) 
    pca = PCA(n_components=2) 


    X_pca = pca.fit_transform(X) 


    print('----shape of mean matrix------')
    print(pca.mean_.shape)

    print('----shape of eigenvectors matrix-----')
    print(pca.components_)
    print(pca.components_.shape)
    #plt.plot(np.transpose(pca.components_))
    print('---shape of eigenvalues matrix----')
    print(pca.singular_values_)
    print(pca.singular_values_.shape)

    print('---explained variance ratio -----------')
    explained_variance = pca.explained_variance_ratio_ 
    print(explained_variance)

    print('---transformed data--------------------')
    transformed_data = pd.DataFrame(data = X_pca
             , columns = ['principal component 1', 'principal component 2'])
    transformed_data['Country'] = df.iloc[:,0]
    print(transformed_data)
    print(transformed_data.shape)

    sns.scatterplot(data=transformed_data, x='principal component 1', y = 'principal component 2', hue='Country')
    plt.legend(loc='upper center',ncol=3)

    #sns.lmplot(data=transformed_data, x='principal component 1', y = 'principal component 2', hue='Country', fit_reg=False)
    #plt.scatter(transformed_data['principal component 1'], transformed_data['principal component 2'])

# %%
main()
# Out:
# ----shape of training data------
# (13, 20)
# ----shape of mean matrix------
# (20,)
# ----shape of eigenvectors matrix-----
# [[-0.00783844 -0.25088295 -0.26379551 -0.3075616  -0.24333708 -0.19829443
#   -0.27740544 -0.17786406 -0.16708899 -0.27206292 -0.28289229 -0.219254
#   -0.35276092 -0.2361455   0.20987329 -0.11823783 -0.19339383  0.14145774
#   -0.13612727 -0.14655957]
#  [-0.4084629   0.29072317  0.08012012 -0.16292522  0.15635054  0.27659622
#    0.21002179 -0.1021976  -0.43127954 -0.30435236 -0.03059694 -0.13242838
#    0.08723895  0.26308945 -0.04367603  0.09016861 -0.31240199 -0.02485444
#    0.02732938 -0.27792015]]
# (2, 20)
# ---shape of eigenvalues matrix----
# [9.34475792 6.59167706]
# (2,)
# ---explained variance ratio -----------
# [0.33586346 0.16711618]
# ---transformed data--------------------
#     principal component 1  principal component 2      Country
# 0               -1.485853              -0.844894      Germany
# ...
